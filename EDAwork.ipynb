# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset1.csv')

# %%
df.head()
# Out:
#   MUSCLE_ACHES TIREDNESS SORE_THROAT RUNNY_NOSE STUFFY_NOSE FEVER NAUSEA  \
# 0           No       Yes          No        Yes          No    No     No
# 1           No       Yes          No         No          No    No     No
# 2          Yes       Yes         Yes         No          No    No     No
# 3           No        No         Yes        Yes          No    No     No
# 4           No       Yes          No        Yes          No    No     No
#
#   VOMITING DIARRHEA SHORTNESS_OF_BREATH DIFFICULTY_BREATHING LOSS_OF_TASTE  \
# 0       No       No                  No                   No           Yes
# 1       No       No                  No                   No           Yes
# 2       No       No                  No                   No           Yes
# 3       No       No                  No                   No           Yes
# 4       No       No                  No                   No           Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44453 entries, 0 to 44452
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MUSCLE_ACHES          44453 non-null  object
#  1   TIREDNESS             44453 non-null  object
#  2   SORE_THROAT           44453 non-null  object
#  3   RUNNY_NOSE            44453 non-null  object
#  4   STUFFY_NOSE           44453 non-null  object
#  5   FEVER                 44453 non-null  object
#  6   NAUSEA                44453 non-null  object
#  7   VOMITING              44453 non-null  object
#  8   DIARRHEA              44453 non-null  object
#  9   SHORTNESS_OF_BREATH   44453 non-null  object
#  10  DIFFICULTY_BREATHING  44453 non-null  object
#  11  LOSS_OF_TASTE         44453 non-null  object
#  12  LOSS_OF_SMELL         44453 non-null  object
#  13  ITCHY_NOSE            44453 non-null  object
#  14  ITCHY_EYES            44453 non-null  object
# ...

# %%
plt.figure(figsize=(10,5))
df['TYPE'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
cat_vars = df.select_dtypes(include='object').columns.tolist()

if 'TYPE' in cat_vars:
    cat_vars.remove('TYPE')

num_cols = len(cat_vars)
num_rows = (num_cols + 2)//3
fig, axs = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))
axs = axs.flatten()

for i, var in enumerate(cat_vars):
    top_values = df[var].value_counts().index
    filtered_df = df[df[var].isin(top_values)]
    sns.countplot(x=var, data=filtered_df, ax=axs[i])
    axs[i].set_title(var)
    axs[i].tick_params(axis='x', rotation=90)
    

if num_cols <len(axs):
    for i in range(num_cols, len(axs)):
        fig.delaxes(axs[i])
        
fig.tight_layout()

plt.show()

# %%
cat_vars = df.select_dtypes(include='object').columns.tolist()

if 'TYPE' in cat_vars:
    cat_vars.remove('TYPE')

num_cols = len(cat_vars)
num_rows = (num_cols + 2)//3
fig, axs = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))
axs = axs.flatten()

for i, var in enumerate(cat_vars):
    top_values = df[var].value_counts().index
    filtered_df = df[df[var].isin(top_values)]
    #sns.countplot(x='TYPE', data=filtered_df, hue=num_cols, palette='BuPu',ax=axs[i])
    sns.countplot(x=var, hue= 'TYPE', data=filtered_df, ax=axs[i])
    axs[i].set_title(var)
    axs[i].tick_params(axis='x', rotation=90)
    

if num_cols <len(axs):
    for i in range(num_cols, len(axs)):
        fig.delaxes(axs[i])
        
fig.tight_layout()

plt.show()
